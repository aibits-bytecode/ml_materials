# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ### Fillna values

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./data/homeprices.csv')
df1.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       NaN   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
# In here we are going to use the median for the missing value
import math 
median_bedrooms = math.floor(df1.bedrooms.median())
median_bedrooms
# Out:
# 4

# %%
df1.bedrooms = df1.bedrooms.fillna(median_bedrooms)
df1.head()
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       4.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %% [markdown]
# =============================================================================

# %% [markdown]
# ## Categorical values

# %%
df = pd.read_csv('./data/homeprices 2.csv')
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %% [markdown]
# In here we can see string values in the data frame <br>
# what we have to do now 🤯

# %% [markdown]
# ### Label encoding <br>
# Use integers to represent the string values

# %% [markdown]
# ![Screenshot%202023-05-21%20at%2011.44.22.png](attachment:Screenshot%202023-05-21%20at%2011.44.22.png)

# %% [markdown]
# Drawback is model would be think monroe is better than west windsor or wiseversa

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_labelEncoder = df
df_labelEncoder.town = le.fit_transform(df_labelEncoder.town)
df_labelEncoder
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %% [markdown]
# ### One hot encoding

# %% [markdown]
# ![Screenshot%202023-05-21%20at%2011.50.47.png](attachment:Screenshot%202023-05-21%20at%2011.50.47.png)

# %%
df.head()
# Out:
#               town  area   price
# 0  monroe township  2600  550000
# 1  monroe township  3000  565000
# 2  monroe township  3200  610000
# 3  monroe township  3600  680000
# 4  monroe township  4000  725000

# %%
df_town_dummies = pd.get_dummies(df.town)
df_town_dummies
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
df_concat = pd.concat([df,df_town_dummies], axis=1)
df_concat
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
df_concat_last = df_concat.drop(['west windsor','town'], axis=1)
df_concat_last
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %% [markdown]
# In sklearn it knows of the dummy variable trap and it drops the column automatically<br>
# But better to drop it before

# %% [markdown]
# =====================================================================================

# %% [markdown]
# ### Split for model creation

# %% [markdown]
# ### Kfold cross validation

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
dir(digits)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'images', 'target', 'target_names']

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
lr = LogisticRegression()
rf = RandomForestClassifier()

# %%
cross_val_score(lr,digits.data,digits.target)
# Out:
# /Users/chandimajayamina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/chandimajayamina/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
cross_val_score(rf,digits.data,digits.target,cv=3)
# Out:
# array([0.93155259, 0.95826377, 0.92654424])

# %% [markdown]
# ============================================================================================

# %% [markdown]
# # Model Evaluation

# %% [markdown]
# Confusion matrix

# %%
# from sklearn.metrics import confusion_matrix
# cm = confusion_matrix(y_test,y_predicted)

# %%
# import seaborn as sns
# plt.figure(figsize=(10,7))
# sns.heatmap(cm, annot=True)
# plt.xlabel('PREDICTED')
# plt.ylabel('TRUTH')

# %% [markdown]
# ======================================================================================================

# %% [markdown]
# # Model Saving

# %%
# # Loading the model
# import pickle
# with open('./data/Logisticregression_Digit_classification','rb') as f:
#     model = pickle.load(f)

# %%
# # Saving the model
# import pickle
# with open('./data/Logisticregression_Digit_classification2','wb') as f:
#     pickle.dump(model,f)
